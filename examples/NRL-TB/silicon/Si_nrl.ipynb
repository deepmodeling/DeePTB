# %% [markdown]
# # **DeePTB** V2.0 | NRL-TB 参数化使用案例

# %% [markdown]
# <div style="color:black; background-color:#FFF3E9; border: 1px solid #FFE0C3; border-radius: 10px; margin-bottom:1rem">
#     <p style="margin:1rem; padding-left: 1rem; line-height: 2.5;">
#         ©️ <b><i>Copyright 2024 @ Authors</i></b><br/>
#         作者: <a style="font-weight:normal" href="mailto:guqq@pku.edu.cn">顾强强 📨 </a> </a></b></i><br/>
#         日期：2024-04-09<br/>
#         共享协议：本作品采用<a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">知识共享署名-非商业性使用-相同方式共享 4.0 国际许可协议</a>进行许可。</i><br/>
#         快速开始：点击上方的 <span style="background-color:rgb(85, 91, 228); color:white; padding: 3px; border-radius: 5px;box-shadow: 2px 2px 3px rgba(0, 0, 0, 0.3); font-size:0.75rem;">开始连接</span> 按钮，稍等片刻即可运行。
#     </p>
# </div>

# %% [markdown]
# <p style="color:purple; font-weight:bold">DeePTB是使用深度学习构建第一性原理精度的紧束缚（TB）模型的方法，可用于加速材料的电子结构计算。目前该软件已经迭代更新至v2.0 版本。</p>
#
# **本教程主要介绍DeePTB 如何读取转换NRL TB 参数、加载模型及模型优化训练**
#
# 完成本案例你将：
# 1. 了解 NRL-TB 方法的基本知识
# 2. 了解 DeePTB 加载NRL-TB 参数的方法
#
# 关联阅读: **DeePTB** V2.0 快速上手指南 | 训练 Silicon 的紧束缚模型模型

# %% [markdown]
# ## 1. NRL-TB 简介
#
# NRL-TB 是一种基于紧束缚方法的电子结构计算方法，它是由美国海军研究实验室（NRL）开发的。NRL-TB 方法的基本思想是将晶体的电子结构问题转化为一个紧束缚模型，通过求解紧束缚模型的本征值问题来获得晶体的电子结构信息。NRL-TB 方法的优点是可以通过调整紧束缚模型的参数来模拟不同的晶体结构，从而实现对晶体的电子结构计算。
#
# 目前该参数化方法已经被整合到 DeePTB 中，可以通过 DeePTB 加载 NRL-TB 参数来进行电子结构计算。
#
# 了解更多 NRL-TB 信息，请阅读相关文献如 N. Bernstein, et. al. Phys. Rev. B 62, 4477 (2000).

# %% [markdown]
# ## 2. DeePTB 转换 NRL-TB 参数

# %%
import os
os.chdir('./examples/NRL-TB/silicon')

# %%
ls
# Out:
# Si_sp.par           in_band.json        nrl_out/            plot_json_v2.ipynb
# Si_spd.par          input_n2j.json      nrlspd/             plot_v2.ipynb
# band/               input_sp.json       nrlspd_frzoverlap/  run.sh
# bandstructure.npy   input_spd.json      outv2/              v1/
# data/               input_spd_fz.json   outv2spd/

# %%
# !dptb n2j -h
# Out:
# usage: dptb n2j [-h] [-v {DEBUG,3,INFO,2,WARNING,1,ERROR,0}] [-l LOG_PATH]
#                 [-nrl NRL_FILE] [-o OUTDIR]
#                 INPUT
#
# positional arguments:
#   INPUT                 the input parameter file in json or yaml format
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -v {DEBUG,3,INFO,2,WARNING,1,ERROR,0}, --log-level {DEBUG,3,INFO,2,WARNING,1,ERROR,0}
#                         set verbosity level by string or number, 0=ERROR,
#                         1=WARNING, 2=INFO and 3=DEBUG (default: INFO)
#   -l LOG_PATH, --log-path LOG_PATH
#                         set log file to log messages to disk, if not
#                         specified, the logs will only be output to console
#                         (default: None)
#   -nrl NRL_FILE, --nrl_file NRL_FILE
#                         The NRL file name (default: None)
#   -o OUTDIR, --outdir OUTDIR
#                         The output files to save the transfered model and
#                         updated input. (default: ./)

# %%
# !dptb n2j input_n2j.json -nrl Si_spd.par -o nrl_out
# Out:
# DEEPTB INFO    System: Silicon (Si) -- full spd parametrization -- onsite t2g=eg -- 22 October 1999
# DEEPTB INFO    num of atom type: 1
# DEEPTB INFO    The NRL parameters are successfully transferred to DPTB.
# DEEPTB INFO    Please check the input json file and modify the parameters if necessary.
# DEEPTB INFO    !!!!!
# DEEPTB INFO    Important: recommend to set the info.json r_max and oer_max >= 6.6147151362875 Ang
# DEEPTB INFO    !!!!!
# DEEPTB INFO    NRL file Si_spd.par has been converted to nrl_out/nrl_ckpt.json.
# DEEPTB INFO    INPUT json is updated to nrl_out/input_nrl_auto.json.
# DEEPTB INFO    Please check the json file and modify the parameters if necessary.

# %%
ls  ./nrl_out
# Out:
# input_nrl_auto.json  nrl_ckpt.json

# %% [markdown]
# ## 3. DeePTB 加载 NRL-TB 参数，绘制能带

# %%
from dptb.nn.build import build_model
from dptb.postprocess.bandstructure.band import Band
import  matplotlib.pyplot  as plt
import numpy as np
from ase.io import read
from dptb.data import AtomicData, AtomicDataDict
from dptb.nn.nnsk import NNSK
import json
import torch

# %%
#set the band structure task
model = build_model(checkpoint= "./nrl_out/nrl_ckpt.json")

jdata={   
    "task_options": {
        "task": "band",
        "kline_type":"abacus",
        "kpath":[[0.0000000000,  0.0000000000,   0.0000000000,   50],   
                [0.5000000000,   0.0000000000,   0.5000000000,   50],               
                [0.6250000000,   0.2500000000,   0.6250000000,   1],    
                [0.3750000000,   0.3750000000,   0.7500000000,   50],     
                [0.0000000000,   0.0000000000,   0.0000000000,   50],    
                [0.5000000000,   0.5000000000,   0.5000000000,   50],                
                [0.5000000000,   0.2500000000,   0.7500000000,   50],               
                [0.5000000000,   0.0000000000,   0.5000000000,   1 ]
                ],
        "klabels":["G","X","X/U","K","G","L","W","X"],
        "nel_atom":{"Si":4},
        "E_fermi":5.832744121551514,
        "emin":-15,
        "emax":10,
        "ref_band": "./data/kpath.0/eigenvalues.npy"
    }
}

stru_data = "./data/silicon.vasp"
AtomicData_options = {"r_max": 5.0, "oer_max":6.6147151362875, "pbc": True}

kpath_kwargs = jdata["task_options"]
bcal = Band(model=model, 
            use_gui=True, 
            results_path='./', 
            device=model.device)

eigenstatus = bcal.get_bands(data=stru_data, 
               kpath_kwargs=kpath_kwargs, 
               AtomicData_options=AtomicData_options)


bcal.band_plot(ref_band = kpath_kwargs["ref_band"],
               E_fermi = kpath_kwargs["E_fermi"],
               emin = kpath_kwargs["emin"],
               emax = kpath_kwargs["emax"])

# %% [markdown]
# ## 4. DeePTB 模型优化训练

# %%
! dptb train input_spd_fz.json -i ./nrl_out/nrl_ckpt.json -o ./nrl_train_fz
# Out:
# Processing dataset...
# Loading data:   0%|                                       | 0/1 [00:00<?, ?it/s]/Users/aisiqg/Software/venv/pydptb/lib/python3.9/site-packages/dptb/data/AtomicData.py:922: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:212.)
#   cell_tensor = torch.as_tensor(temp_cell, device=out_device, dtype=out_dtype)
# Loading data: 100%|███████████████████████████████| 1/1 [00:00<00:00, 17.01it/s]
# DEEPTB INFO    Loaded data: Batch(atomic_numbers=[2, 1], batch=[2], bwindow=[1, 2], cell=[1, 3, 3], edge_cell_shift=[92, 3], edge_features=[92, 1], edge_index=[2, 92], edge_overlap=[92, 1], eigenvalue=[1, 61, 14], env_cell_shift=[8, 3], env_index=[2, 8], ewindow=[1, 2], kpoint=[1, 61, 3], node_features=[2, 1], node_soc=[2, 1], node_soc_switch=[1, 1], onsitenv_cell_shift=[92, 3], onsitenv_index=[2, 92], pbc=[1, 3], pos=[2, 3], ptr=[2])
#     processed data size: ~0.01 MB
# DEEPTB INFO    Cached processed data to disk
# Done!
# DEEPTB INFO    The ['overlap_param'] are frozen!
# DEEPTB INFO    The ['overlap_param'] are frozen!
# DEEPTB INFO    The ['overlap_param'] are frozen!
# DEEPTB INFO    checkpoint saved as nnsk.iter1
# DEEPTB INFO    Epoch 1 summary:	train_loss: 0.184356
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep1
# DEEPTB INFO    checkpoint saved as nnsk.iter2
# DEEPTB INFO    Epoch 2 summary:	train_loss: 0.134729
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep2
# DEEPTB INFO    checkpoint saved as nnsk.iter3
# DEEPTB INFO    Epoch 3 summary:	train_loss: 0.077229
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep3
# DEEPTB INFO    checkpoint saved as nnsk.iter4
# DEEPTB INFO    Epoch 4 summary:	train_loss: 0.089876
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter5
# DEEPTB INFO    Epoch 5 summary:	train_loss: 0.099659
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter6
# DEEPTB INFO    Epoch 6 summary:	train_loss: 0.071669
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep6
# DEEPTB INFO    checkpoint saved as nnsk.iter7
# DEEPTB INFO    Epoch 7 summary:	train_loss: 0.070386
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep7
# DEEPTB INFO    checkpoint saved as nnsk.iter8
# DEEPTB INFO    Epoch 8 summary:	train_loss: 0.080483
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter9
# DEEPTB INFO    Epoch 9 summary:	train_loss: 0.066077
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep9
# DEEPTB INFO    checkpoint saved as nnsk.iter10
# DEEPTB INFO    Epoch 10 summary:	train_loss: 0.052017
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep10
# DEEPTB INFO    checkpoint saved as nnsk.iter11
# DEEPTB INFO    Epoch 11 summary:	train_loss: 0.055806
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter12
# DEEPTB INFO    Epoch 12 summary:	train_loss: 0.058792
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter13
# DEEPTB INFO    Epoch 13 summary:	train_loss: 0.053666
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter14
# DEEPTB INFO    Epoch 14 summary:	train_loss: 0.053605
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter15
# DEEPTB INFO    Epoch 15 summary:	train_loss: 0.060056
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter16
# DEEPTB INFO    Epoch 16 summary:	train_loss: 0.059962
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter17
# DEEPTB INFO    Epoch 17 summary:	train_loss: 0.052238
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter18
# DEEPTB INFO    Epoch 18 summary:	train_loss: 0.048192
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep18
# DEEPTB INFO    checkpoint saved as nnsk.iter19
# DEEPTB INFO    Epoch 19 summary:	train_loss: 0.050007
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter20
# DEEPTB INFO    Epoch 20 summary:	train_loss: 0.049880
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter21
# DEEPTB INFO    Epoch 21 summary:	train_loss: 0.047312
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep21
# DEEPTB INFO    checkpoint saved as nnsk.iter22
# DEEPTB INFO    Epoch 22 summary:	train_loss: 0.048289
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter23
# DEEPTB INFO    Epoch 23 summary:	train_loss: 0.051405
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter24
# DEEPTB INFO    Epoch 24 summary:	train_loss: 0.050516
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter25
# DEEPTB INFO    Epoch 25 summary:	train_loss: 0.047274
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep25
# DEEPTB INFO    checkpoint saved as nnsk.iter26
# DEEPTB INFO    Epoch 26 summary:	train_loss: 0.046701
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep26
# DEEPTB INFO    checkpoint saved as nnsk.iter27
# DEEPTB INFO    Epoch 27 summary:	train_loss: 0.047322
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter28
# DEEPTB INFO    Epoch 28 summary:	train_loss: 0.045865
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep28
# DEEPTB INFO    checkpoint saved as nnsk.iter29
# DEEPTB INFO    Epoch 29 summary:	train_loss: 0.044329
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep29
# DEEPTB INFO    checkpoint saved as nnsk.iter30
# DEEPTB INFO    Epoch 30 summary:	train_loss: 0.045056
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter31
# DEEPTB INFO    Epoch 31 summary:	train_loss: 0.045749
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter32
# DEEPTB INFO    Epoch 32 summary:	train_loss: 0.044673
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter33
# DEEPTB INFO    Epoch 33 summary:	train_loss: 0.043986
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep33
# DEEPTB INFO    checkpoint saved as nnsk.iter34
# DEEPTB INFO    Epoch 34 summary:	train_loss: 0.044624
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter35
# DEEPTB INFO    Epoch 35 summary:	train_loss: 0.044589
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter36
# DEEPTB INFO    Epoch 36 summary:	train_loss: 0.043512
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep36
# DEEPTB INFO    checkpoint saved as nnsk.iter37
# DEEPTB INFO    Epoch 37 summary:	train_loss: 0.043140
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep37
# DEEPTB INFO    checkpoint saved as nnsk.iter38
# DEEPTB INFO    Epoch 38 summary:	train_loss: 0.043439
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter39
# DEEPTB INFO    Epoch 39 summary:	train_loss: 0.043099
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep39
# DEEPTB INFO    checkpoint saved as nnsk.iter40
# DEEPTB INFO    Epoch 40 summary:	train_loss: 0.042677
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep40
# DEEPTB INFO    checkpoint saved as nnsk.iter41
# DEEPTB INFO    Epoch 41 summary:	train_loss: 0.043083
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter42
# DEEPTB INFO    Epoch 42 summary:	train_loss: 0.043367
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter43
# DEEPTB INFO    Epoch 43 summary:	train_loss: 0.042868
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter44
# DEEPTB INFO    Epoch 44 summary:	train_loss: 0.042494
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep44
# DEEPTB INFO    checkpoint saved as nnsk.iter45
# DEEPTB INFO    Epoch 45 summary:	train_loss: 0.042531
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter46
# DEEPTB INFO    Epoch 46 summary:	train_loss: 0.042296
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep46
# DEEPTB INFO    checkpoint saved as nnsk.iter47
# DEEPTB INFO    Epoch 47 summary:	train_loss: 0.041994
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep47
# DEEPTB INFO    checkpoint saved as nnsk.iter48
# DEEPTB INFO    Epoch 48 summary:	train_loss: 0.042136
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter49
# DEEPTB INFO    Epoch 49 summary:	train_loss: 0.042241
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter50
# DEEPTB INFO    Epoch 50 summary:	train_loss: 0.041969
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep50
# DEEPTB INFO    checkpoint saved as nnsk.iter51
# DEEPTB INFO    Epoch 51 summary:	train_loss: 0.041800
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep51
# DEEPTB INFO    checkpoint saved as nnsk.iter52
# DEEPTB INFO    Epoch 52 summary:	train_loss: 0.041812
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.iter53
# DEEPTB INFO    Epoch 53 summary:	train_loss: 0.041624
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep53
# DEEPTB INFO    checkpoint saved as nnsk.iter54
# DEEPTB INFO    Epoch 54 summary:	train_loss: 0.041405
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep54
# DEEPTB INFO    checkpoint saved as nnsk.iter55
# DEEPTB INFO    Epoch 55 summary:	train_loss: 0.041395
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep55
# DEEPTB INFO    checkpoint saved as nnsk.iter56
# DEEPTB INFO    Epoch 56 summary:	train_loss: 0.041320
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep56
# DEEPTB INFO    checkpoint saved as nnsk.iter57
# DEEPTB INFO    Epoch 57 summary:	train_loss: 0.041117
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep57
# DEEPTB INFO    checkpoint saved as nnsk.iter58
# DEEPTB INFO    Epoch 58 summary:	train_loss: 0.041045
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep58
# DEEPTB INFO    checkpoint saved as nnsk.iter59
# DEEPTB INFO    Epoch 59 summary:	train_loss: 0.040997
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep59
# DEEPTB INFO    checkpoint saved as nnsk.iter60
# DEEPTB INFO    Epoch 60 summary:	train_loss: 0.040796
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep60
# DEEPTB INFO    checkpoint saved as nnsk.iter61
# DEEPTB INFO    Epoch 61 summary:	train_loss: 0.040614
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep61
# DEEPTB INFO    checkpoint saved as nnsk.iter62
# DEEPTB INFO    Epoch 62 summary:	train_loss: 0.040490
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep62
# DEEPTB INFO    checkpoint saved as nnsk.iter63
# DEEPTB INFO    Epoch 63 summary:	train_loss: 0.040281
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep63
# DEEPTB INFO    checkpoint saved as nnsk.iter64
# DEEPTB INFO    Epoch 64 summary:	train_loss: 0.040072
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep64
# DEEPTB INFO    checkpoint saved as nnsk.iter65
# DEEPTB INFO    Epoch 65 summary:	train_loss: 0.039940
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep65
# DEEPTB INFO    checkpoint saved as nnsk.iter66
# DEEPTB INFO    Epoch 66 summary:	train_loss: 0.039748
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep66
# DEEPTB INFO    checkpoint saved as nnsk.iter67
# DEEPTB INFO    Epoch 67 summary:	train_loss: 0.039500
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep67
# DEEPTB INFO    checkpoint saved as nnsk.iter68
# DEEPTB INFO    Epoch 68 summary:	train_loss: 0.039290
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep68
# DEEPTB INFO    checkpoint saved as nnsk.iter69
# DEEPTB INFO    Epoch 69 summary:	train_loss: 0.039061
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep69
# DEEPTB INFO    checkpoint saved as nnsk.iter70
# DEEPTB INFO    Epoch 70 summary:	train_loss: 0.038800
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep70
# DEEPTB INFO    checkpoint saved as nnsk.iter71
# DEEPTB INFO    Epoch 71 summary:	train_loss: 0.038590
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep71
# DEEPTB INFO    checkpoint saved as nnsk.iter72
# DEEPTB INFO    Epoch 72 summary:	train_loss: 0.038401
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep72
# DEEPTB INFO    checkpoint saved as nnsk.iter73
# DEEPTB INFO    Epoch 73 summary:	train_loss: 0.038202
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep73
# DEEPTB INFO    checkpoint saved as nnsk.iter74
# DEEPTB INFO    Epoch 74 summary:	train_loss: 0.038057
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep74
# DEEPTB INFO    checkpoint saved as nnsk.iter75
# DEEPTB INFO    Epoch 75 summary:	train_loss: 0.037949
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep75
# DEEPTB INFO    checkpoint saved as nnsk.iter76
# DEEPTB INFO    Epoch 76 summary:	train_loss: 0.037834
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep76
# DEEPTB INFO    checkpoint saved as nnsk.iter77
# DEEPTB INFO    Epoch 77 summary:	train_loss: 0.037755
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep77
# DEEPTB INFO    checkpoint saved as nnsk.iter78
# DEEPTB INFO    Epoch 78 summary:	train_loss: 0.037699
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep78
# DEEPTB INFO    checkpoint saved as nnsk.iter79
# DEEPTB INFO    Epoch 79 summary:	train_loss: 0.037620
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep79
# DEEPTB INFO    checkpoint saved as nnsk.iter80
# DEEPTB INFO    Epoch 80 summary:	train_loss: 0.037545
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep80
# DEEPTB INFO    checkpoint saved as nnsk.iter81
# DEEPTB INFO    Epoch 81 summary:	train_loss: 0.037453
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep81
# DEEPTB INFO    checkpoint saved as nnsk.iter82
# DEEPTB INFO    Epoch 82 summary:	train_loss: 0.037305
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep82
# DEEPTB INFO    checkpoint saved as nnsk.iter83
# DEEPTB INFO    Epoch 83 summary:	train_loss: 0.037131
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep83
# DEEPTB INFO    checkpoint saved as nnsk.iter84
# DEEPTB INFO    Epoch 84 summary:	train_loss: 0.036945
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep84
# DEEPTB INFO    checkpoint saved as nnsk.iter85
# DEEPTB INFO    Epoch 85 summary:	train_loss: 0.036750
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep85
# DEEPTB INFO    checkpoint saved as nnsk.iter86
# DEEPTB INFO    Epoch 86 summary:	train_loss: 0.036587
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep86
# DEEPTB INFO    checkpoint saved as nnsk.iter87
# DEEPTB INFO    Epoch 87 summary:	train_loss: 0.036455
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep87
# DEEPTB INFO    checkpoint saved as nnsk.iter88
# DEEPTB INFO    Epoch 88 summary:	train_loss: 0.036336
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep88
# DEEPTB INFO    checkpoint saved as nnsk.iter89
# DEEPTB INFO    Epoch 89 summary:	train_loss: 0.036239
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep89
# DEEPTB INFO    checkpoint saved as nnsk.iter90
# DEEPTB INFO    Epoch 90 summary:	train_loss: 0.036155
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep90
# DEEPTB INFO    checkpoint saved as nnsk.iter91
# DEEPTB INFO    Epoch 91 summary:	train_loss: 0.036077
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep91
# DEEPTB INFO    checkpoint saved as nnsk.iter92
# DEEPTB INFO    Epoch 92 summary:	train_loss: 0.036021
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep92
# DEEPTB INFO    checkpoint saved as nnsk.iter93
# DEEPTB INFO    Epoch 93 summary:	train_loss: 0.035972
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep93
# DEEPTB INFO    checkpoint saved as nnsk.iter94
# DEEPTB INFO    Epoch 94 summary:	train_loss: 0.035907
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep94
# DEEPTB INFO    checkpoint saved as nnsk.iter95
# DEEPTB INFO    Epoch 95 summary:	train_loss: 0.035822
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep95
# DEEPTB INFO    checkpoint saved as nnsk.iter96
# DEEPTB INFO    Epoch 96 summary:	train_loss: 0.035714
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep96
# DEEPTB INFO    checkpoint saved as nnsk.iter97
# DEEPTB INFO    Epoch 97 summary:	train_loss: 0.035596
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep97
# DEEPTB INFO    checkpoint saved as nnsk.iter98
# DEEPTB INFO    Epoch 98 summary:	train_loss: 0.035492
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep98
# DEEPTB INFO    checkpoint saved as nnsk.iter99
# DEEPTB INFO    Epoch 99 summary:	train_loss: 0.035404
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep99
# DEEPTB INFO    iteration:100	train_loss: 0.035327  (0.035536)	lr: 0.009057
# DEEPTB INFO    checkpoint saved as nnsk.iter100
# DEEPTB INFO    Epoch 100 summary:	train_loss: 0.035327
# ################################################################################################################################################################
# DEEPTB INFO    checkpoint saved as nnsk.ep100
# DEEPTB INFO    finished training
# DEEPTB INFO    wall time: 8.092 s

# %%
#set the band structure task
model = build_model(checkpoint= "./nrl_train_fz/checkpoint/nnsk.ep100.pth")

jdata={   
    "task_options": {
        "task": "band",
        "kline_type":"abacus",
        "kpath":[[0.0000000000,  0.0000000000,   0.0000000000,   50],   
                [0.5000000000,   0.0000000000,   0.5000000000,   50],               
                [0.6250000000,   0.2500000000,   0.6250000000,   1],    
                [0.3750000000,   0.3750000000,   0.7500000000,   50],     
                [0.0000000000,   0.0000000000,   0.0000000000,   50],    
                [0.5000000000,   0.5000000000,   0.5000000000,   50],                
                [0.5000000000,   0.2500000000,   0.7500000000,   50],               
                [0.5000000000,   0.0000000000,   0.5000000000,   1 ]
                ],
        "klabels":["G","X","X/U","K","G","L","W","X"],
        "nel_atom":{"Si":4},
        "E_fermi":5.832744121551514,
        "emin":-15,
        "emax":10,
        "ref_band": "./data/kpath.0/eigenvalues.npy"
    }
}

stru_data = "./data/silicon.vasp"
AtomicData_options = {"r_max": 5.0, "oer_max":6.6147151362875, "pbc": True}

kpath_kwargs = jdata["task_options"]
bcal = Band(model=model, 
            use_gui=True, 
            results_path='./', 
            device=model.device)

eigenstatus = bcal.get_bands(data=stru_data, 
               kpath_kwargs=kpath_kwargs, 
               AtomicData_options=AtomicData_options)


bcal.band_plot(ref_band = kpath_kwargs["ref_band"],
               E_fermi = kpath_kwargs["E_fermi"],
               emin = kpath_kwargs["emin"],
               emax = kpath_kwargs["emax"])
