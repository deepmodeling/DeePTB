# %%
from dptb.nn.build import build_model
from dptb.postprocess.bandstructure.band import Band
import  matplotlib.pyplot  as plt
import numpy as np
from ase.io import read
from dptb.data import AtomicData, AtomicDataDict
from dptb.nn.nnsk import NNSK
import json
import torch

# %%
# The settings for the model. must be provided.
run_opt = {
        "init_model": "./reference/non_soc/v1ckpt/best_nnsk_c6.0w0.1.json",
        "restart": None,
        "freeze": False,
        "train_soc": False,
        "log_path": None,
        "log_level": None
    }

model_option = {
    "nnsk": {
        "onsite": {"method": "strain","rs":6, "w": 0.1},
        "hopping": {"method": "powerlaw", "rs":6.0, "w": 0.1},
        "soc":{},
        "push": False,
        "freeze": False
    }
}
common_options = {
"basis": {
    "Sn": ["5s","5p","d*"]
},
"device": "cpu",
"dtype": "float32",
"overlap": False
}

# Build the model
model = build_model(run_opt['init_model'], model_option, common_options)
# Out:
# The model option std in nnsk is not defined in input model_options, set to 0.01.

# %%
jdata={
        "kline_type":"abacus",
        "kpath":[[0.0000000000,   0.0000000000,   0.0000000000,   30],   
                 [0.5000000000,   0.0000000000,   0.5000000000,   30],               
                 [0.6250000000,   0.2500000000,   0.6250000000,   30],    
                 [0.3750000000,   0.3750000000,   0.7500000000,   30],     
                 [0.0000000000,   0.0000000000,   0.0000000000,   30],    
                 [0.5000000000,   0.5000000000,   0.5000000000,   30],                
                 [0.5000000000,   0.2500000000,   0.7500000000,   30],               
                 [0.5000000000,   0.0000000000,   0.5000000000,   1 ]
                 ],
        "klabels":['G','X','U','K','G','L','W','X'],
        "emin":-10,
        "emax":10
    }

# %%
# calculate the band structure
kpath_kwargs = jdata
bcal = Band(model=model, 
            use_gui=True, 
            results_path='./', 
            device=model.device)

stru_data = "./data/non_soc/Sn.vasp"
AtomicData_options = {"r_max": 6.0, "oer_max":3.0, "pbc": True}

eigenstatus = bcal.get_bands(data=stru_data, 
               kpath_kwargs=kpath_kwargs, 
               AtomicData_options=AtomicData_options)

# %%
# plot the band structure w.r.t. DFT results
#band = np.load(f'./data/kpath.0/eigenvalues.npy')
band = np.load('./data/non_soc/set.0/eigenvalues.npy')
if len(band.shape)==3:
    band = band[0,:,:]
plt.figure(figsize=(6,6),dpi=72)
#plt.plot(eigenstatus['xlist'], band[:,:] - np.min(band[:,:]),'k--',lw=1)
plt.plot(eigenstatus['xlist'][::5], band[::5] - np.min(band), 'ko')
plt.plot(eigenstatus['xlist'], eigenstatus['eigenvalues']- np.min(eigenstatus['eigenvalues']), 'r--',lw=2)

plt.ylim(-2,25)

for ii in eigenstatus['high_sym_kpoints']:
    plt.axvline(ii,color='gray',lw=1,ls='--')
plt.tick_params(direction='in')

plt.xlim(eigenstatus['xlist'].min(),eigenstatus['xlist'].max())

plt.ylabel('E - EF (eV)',fontsize=12)
plt.yticks(fontsize=12)
plt.xticks(eigenstatus['high_sym_kpoints'], eigenstatus['labels'], fontsize=12)
#plt.savefig(f'{self.results_path}/band.png',dpi=300)
plt.show()

# %%
band = np.loadtxt('./data/non_soc/BANDS_1.dat')

# %%
# Out:
# [<matplotlib.lines.Line2D at 0x7f985806f580>,
#  <matplotlib.lines.Line2D at 0x7f98710924f0>,
#  <matplotlib.lines.Line2D at 0x7f988a55bc70>,
#  <matplotlib.lines.Line2D at 0x7f9871098310>,
#  <matplotlib.lines.Line2D at 0x7f98711ba8b0>,
#  <matplotlib.lines.Line2D at 0x7f98887e8fa0>,
#  <matplotlib.lines.Line2D at 0x7f98887e8dc0>,
#  <matplotlib.lines.Line2D at 0x7f988a6081f0>,
#  <matplotlib.lines.Line2D at 0x7f988a608400>,
#  <matplotlib.lines.Line2D at 0x7f988a6084f0>,
#  <matplotlib.lines.Line2D at 0x7f988a6085e0>,
#  <matplotlib.lines.Line2D at 0x7f988a6086d0>,
#  <matplotlib.lines.Line2D at 0x7f988a6087c0>,
#  <matplotlib.lines.Line2D at 0x7f988a6088b0>]
