# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

# %%
sk_path = "../../../dftb_skfiles/ParameterSets/"

skdict = torch.load(sk_path + "prior.pth")

# %%
bondtype= 'S-Mo'
momoh = skdict["Hopping"][bondtype].numpy()
xlist = skdict["Distance"][bondtype]
plt.plot(xlist, momoh.T)
plt.xlim(2,5)
plt.ylim(-5,5)
# Out:
# (-5.0, 5.0)

# %%
bondtype= 'Mo-S'
momoh = skdict["Hopping"][bondtype].numpy()
xlist = skdict["Distance"][bondtype]
plt.plot(xlist, momoh.T)
plt.xlim(2,5)
plt.ylim(-5,5)
# Out:
# (-5.0, 5.0)

# %%
skdict.keys()
# Out:
# dict_keys(['OnsiteE', 'Hopping', 'Overlap', 'Distance', 'HubdU', 'Occu'])

# %%
skdict["Occu"]['S']
# Out:
# tensor([2., 4., 0.])

# %%
skdict["OnsiteE"]['S']
# Out:
# tensor([-17.2485,  -7.0089,   1.1436])
